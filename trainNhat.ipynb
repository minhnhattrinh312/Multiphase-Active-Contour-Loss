# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tfa-nightly
# !pip install import-ipynb
import import_ipynb
import tensorflow as tf
import numpy as np
import os
import scipy.io as sio
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
from tqdm import tqdm
from fastprogress import master_bar, progress_bar
# %cd '/content/drive/MyDrive/MS loss'
# Out:
# Collecting tfa-nightly
#   Downloading https://files.pythonhosted.org/packages/16/09/04c861706f155122d096b3058735e69827a2e1389c1acfcc4b0c987717fb/tfa_nightly-0.12.0.dev20201118111955-cp36-cp36m-manylinux2010_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 5.3MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.6/dist-packages (from tfa-nightly) (2.7.1)
# Installing collected packages: tfa-nightly
# Successfully installed tfa-nightly-0.12.0.dev20201118111955
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp36-none-any.whl size=2976 sha256=117e364c0581128e647e7d468746453bcd6b6ecdfc62bc323fe0c386926a47d2
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# /content/drive/MyDrive/MS loss

# %%
# %run UnetModel.ipynb
# %run MumfordLoss.ipynb
# %run augment_data.ipynb
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 576         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# swish (Swish)                   (None, 128, 128, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36864       swish[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# swish_1 (Swish)                 (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1, 1, 64)     0           swish_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 1, 16)     1040        lambda[0][0]
# __________________________________________________________________________________________________
# swish_2 (Swish)                 (None, 1, 1, 16)     0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 64)     1088        swish_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 1, 64)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# output_block_1 (Multiply)       (None, 128, 128, 64) 0           activation[0][0]
#                                                                  swish_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           output_block_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 128)  73728       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# swish_3 (Swish)                 (None, 64, 64, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  147456      swish_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# swish_4 (Swish)                 (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 1, 128)    0           swish_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 32)     4128        lambda_1[0][0]
# __________________________________________________________________________________________________
# swish_5 (Swish)                 (None, 1, 1, 32)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 128)    4224        swish_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 1, 128)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# output_block_2 (Multiply)       (None, 64, 64, 128)  0           activation_1[0][0]
#                                                                  swish_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           output_block_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 256)  294912      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# swish_6 (Swish)                 (None, 32, 32, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  589824      swish_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# swish_7 (Swish)                 (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 1, 256)    0           swish_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 1, 64)     16448       lambda_2[0][0]
# __________________________________________________________________________________________________
# swish_8 (Swish)                 (None, 1, 1, 64)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 256)    16640       swish_8[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 1, 256)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# output_block_3 (Multiply)       (None, 32, 32, 256)  0           activation_2[0][0]
#                                                                  swish_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           output_block_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  1179648     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# swish_9 (Swish)                 (None, 16, 16, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 512)  2359296     swish_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# swish_10 (Swish)                (None, 16, 16, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 1, 512)    0           swish_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 128)    65664       lambda_3[0][0]
# __________________________________________________________________________________________________
# swish_11 (Swish)                (None, 1, 1, 128)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 1, 512)    66048       swish_11[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 1, 512)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# output_block_4 (Multiply)       (None, 16, 16, 512)  0           activation_3[0][0]
#                                                                  swish_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)    0           output_block_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 1024)   4718592     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 1024)   4096        conv2d_16[0][0]
# __________________________________________________________________________________________________
# swish_12 (Swish)                (None, 8, 8, 1024)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 1024)   9437184     swish_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 1024)   4096        conv2d_17[0][0]
# __________________________________________________________________________________________________
# swish_13 (Swish)                (None, 8, 8, 1024)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 1, 1024)   0           swish_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 1, 256)    262400      lambda_4[0][0]
# __________________________________________________________________________________________________
# swish_14 (Swish)                (None, 1, 1, 256)    0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 1024)   263168      swish_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 1024)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# output_block_5 (Multiply)       (None, 8, 8, 1024)   0           activation_4[0][0]
#                                                                  swish_13[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 512)    524288      output_block_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 512)  262144      output_block_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 512)  2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  1049088     batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 16, 16, 512) 0           batch_normalization_11[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# swish_15 (Swish)                (None, 16, 16, 512)  0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 1)    512         swish_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 1)    4           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 1)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 512)  2097664     output_block_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 16, 16, 512) 0           activation_5[0][0]
#                                                                  output_block_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 1024) 0           conv2d_transpose[0][0]
#                                                                  tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 512)  4718592     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 512)  2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# swish_16 (Swish)                (None, 16, 16, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 512)  2359296     swish_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 512)  2048        conv2d_24[0][0]
# __________________________________________________________________________________________________
# swish_17 (Swish)                (None, 16, 16, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 1, 512)    0           swish_17[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1, 1, 128)    65664       lambda_5[0][0]
# __________________________________________________________________________________________________
# swish_18 (Swish)                (None, 1, 1, 128)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 1, 1, 512)    66048       swish_18[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 1, 512)    0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 16, 16, 512)  0           activation_6[0][0]
#                                                                  swish_17[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 256)  131072      multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 256)  65536       output_block_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 256)  1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 256)  262400      batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 32, 32, 256) 0           batch_normalization_16[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# swish_19 (Swish)                (None, 32, 32, 256)  0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 1)    256         swish_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 1)    4           conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 1)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 256)  524544      multiply[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None, 32, 32, 256) 0           activation_7[0][0]
#                                                                  output_block_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_2[0][0]
#                                                                  tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 256)  1179648     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# swish_20 (Swish)                (None, 32, 32, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 256)  589824      swish_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 256)  1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# swish_21 (Swish)                (None, 32, 32, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1, 1, 256)    0           swish_21[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 1, 1, 64)     16448       lambda_6[0][0]
# __________________________________________________________________________________________________
# swish_22 (Swish)                (None, 1, 1, 64)     0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 1, 1, 256)    16640       swish_22[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1, 1, 256)    0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 32, 32, 256)  0           activation_8[0][0]
#                                                                  swish_21[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 128)  32768       multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 128)  16384       output_block_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 128)  65664       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 64, 64, 128) 0           batch_normalization_21[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# swish_23 (Swish)                (None, 64, 64, 128)  0           tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 1)    128         swish_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 1)    4           conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 1)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 128)  131200      multiply_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(None, 64, 64, 128) 0           activation_9[0][0]
#                                                                  output_block_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_4[0][0]
#                                                                  tf_op_layer_Mul_2[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 128)  294912      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# swish_24 (Swish)                (None, 64, 64, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 128)  147456      swish_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 128)  512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# swish_25 (Swish)                (None, 64, 64, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1, 1, 128)    0           swish_25[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 1, 1, 32)     4128        lambda_7[0][0]
# __________________________________________________________________________________________________
# swish_26 (Swish)                (None, 1, 1, 32)     0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 1, 1, 128)    4224        swish_26[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 128)    0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 64, 64, 128)  0           activation_10[0][0]
#                                                                  swish_25[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 64)   8192        multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 64) 4096        output_block_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 128, 128, 64) 256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 64) 16448       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 128, 128, 64 0           batch_normalization_26[0][0]
#                                                                  conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# swish_27 (Swish)                (None, 128, 128, 64) 0           tf_op_layer_AddV2_3[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 1)  64          swish_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128, 128, 1)  4           conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 128, 1)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 64) 32832       multiply_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_3 (TensorFlowOp [(None, 128, 128, 64 0           activation_11[0][0]
#                                                                  output_block_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_6[0][0]
#                                                                  tf_op_layer_Mul_3[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 128, 128, 64) 256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# swish_28 (Swish)                (None, 128, 128, 64) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 64) 36864       swish_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 128, 128, 64) 256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# swish_29 (Swish)                (None, 128, 128, 64) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1, 1, 64)     0           swish_29[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 1, 1, 16)     1040        lambda_8[0][0]
# __________________________________________________________________________________________________
# swish_30 (Swish)                (None, 1, 1, 16)     0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 1, 1, 64)     1088        swish_30[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 1, 64)     0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 128, 128, 64) 0           activation_12[0][0]
#                                                                  swish_29[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 128, 128, 3)  195         multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 128, 3)  0           conv2d_48[0][0]
# ==================================================================================================
# Total params: 34,371,251
# Trainable params: 34,355,627
# Non-trainable params: 15,624
# __________________________________________________________________________________________________

# %%
import keras.backend as K

def dice_coef(y_true, y_pred, smooth=1e-10):
    '''Average dice coefficient per batch.'''
    axes = (1,2,3)
    intersection = K.sum(y_true * y_pred, axis=axes)
    summation = K.sum(y_true + y_pred, axis=axes)
    return K.mean((2.0 * intersection + smooth) / (summation + smooth), axis=0)

def jaccard_coef(y_true, y_pred, smooth=1e-10):
    '''Average jaccard coefficient per batch.'''
    axes = (1,2,3)
    intersection = K.sum(y_true * y_pred, axis=axes)
    union = K.sum(y_true + y_pred, axis=axes) - intersection
    return K.mean( (intersection + smooth) / (union + smooth), axis=0)

# %%
x = np.asarray(np.load('./dataACDCA/x_crop_128.npy'),np.float32)
y = np.load('./dataACDCA/y_crop_128.npy')

# %%
np.random.seed(123)
len_dev = x.shape[0]//5
len_train = x.shape[0] - len_dev
rand_index = np.random.permutation(x.shape[0])
x_test = x[rand_index[:len_dev]]
y_test = y[rand_index[:len_dev]]
x_train = x[rand_index[len_dev:]]
y_train = y[rand_index[len_dev:]]

# %%
# plt.figure(1)
# label_endo = tf.where(y_test == 2.0, 1.0, 0.0)
# label_epi =  tf.where(y_test == 1.0, 1.0, 0.0) + label_endo
# plt.subplot(131),plt.imshow(x[102][...,0],cmap='gray')
# plt.subplot(132),plt.imshow(label_epi[102][...,0],cmap='gray')
# plt.subplot(133),plt.imshow(y_test[102][...,0],cmap='gray')

# %%
BATCH_SIZE = 32
buffer_size = x_train.shape[0]

@tf.function
def gen_image(image,mask):
  # image, mask = brightness(image,mask)
  #image, mask = saturation(image,mask)
  image, mask = flip(image,mask)
  image, mask = rotate_image(image,mask)
  image, mask = normalize(image, mask)
  return image, mask
train_dataset = tf.data.Dataset.from_tensor_slices((x_train,y_train)).shuffle(buffer_size).map(gen_image).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test,y_test)).map(normalize).batch(BATCH_SIZE*2)

# %%
class MSLoss_vs2():
  def levelsetLoss(self,target, output):
    loss = 0.0
    for ich in range(target.shape[3]):
        target_ = target[...,ich:ich+1]    
        pcentroid = tf.reduce_sum(target_ * output, (1,2),keepdims=True)/tf.reduce_sum(output, (1,2),keepdims = True)   
        plevel = target_ - pcentroid
        pLoss = plevel * plevel * output
        loss += tf.reduce_sum(pLoss)
    return loss
      
  def activeContourLoss(self,y_true,y_pred,outDim =3,smooth=0.001):     
    yTrueOnehot = tf.one_hot(tf.squeeze(tf.cast(y_true,tf.uint8),axis=-1), depth = outDim)
    loss =  y_pred * (1-yTrueOnehot) + (1-y_pred)*yTrueOnehot
    return tf.reduce_mean(loss)
    #this is Luac:
    # loss =  - tf.cast(tf.math.log(1-y_pred+smooth),tf.float32) * (1-yTrueOnehot ) - tf.cast(tf.math.log(y_pred+smooth),tf.float32)*yTrueOnehot
    # return tf.reduce_mean(loss)
                    
  def gradientLoss(self,input,penalty = "l1"):

    dH = tf.math.abs(input[:, 1:, :, :] - input[:, :-1, :, :])
    dW = tf.math.abs(input[:, :, 1:, :] - input[:, :, :-1, :])
    if penalty == "l2":
        dH = dH * dH
        dW = dW * dW

    loss =  tf.reduce_sum(dH) +  tf.reduce_sum(dW)
    return loss

# %%
class Mumford_Unet_vs2(MSLoss_vs2):
  def __init__(self,model):
    super().__init__()
    self.model = model
    self.optimizer = None
    self.trainData = None
    self.testData = None
    self.batch_size = BATCH_SIZE
    self.train_step = x_train.shape[0] // self.batch_size +1
    self.learning_rate = 0.001

  def optimizer_fc(self,op_type = "adam", op_param = 0.005):
    if op_type == 'adam':
      self.optimizer =  tf.keras.optimizers.Adam(op_param)
    elif op_type == "nadam":
      self.optimizer =  tf.keras.optimizers.Nadam(op_param)

  def loss(self, image, output, trueLabel, alpha = 1e-3, beta = 0.001):
    # print('\rgradient loss: ', self.gradientLoss(output),' leverset loss: ', self.levelsetLoss(image,output),' active loss: ',self.activeContourLoss(trueLabel, output), end="")
    return alpha * ( self.levelsetLoss(image,output) + beta * self.gradientLoss(output))/self.batch_size + self.activeContourLoss(trueLabel, output)
    # return self.activeContourLoss(trueLabel, output)



  def metrics(self,y_true,y_pred):
    output_standard = tf.expand_dims(tf.argmax(y_pred,axis=-1),axis = -1)
    output_endo = tf.where(output_standard == 2, 1.0, 0.0)
    output_epi =  tf.where(output_standard == 1, 1.0, 0.0) + output_endo
    label_endo = tf.where(y_true == 2, 1.0, 0.0)
    label_epi =  tf.where(y_true == 1, 1.0, 0.0) + label_endo

    dice_coef_endo = dice_coef(label_endo, output_endo)
    dice_coef_epi = dice_coef(label_epi, output_epi)
    jaccards_coef_endo = jaccard_coef(label_endo, output_endo)
    jaccards_coef_epi = jaccard_coef(label_epi, output_epi)
    return dice_coef_endo, dice_coef_epi, jaccards_coef_endo, jaccards_coef_epi

  def evaluateTest(self,testDataset):
    test_dices_endo =  []
    test_dices_epi = []
    test_jaccards_endo =  []
    test_jaccards_epi = []
    for xBatchTest, yBatchTest in testDataset:
      yPredBatchTest = self.model(xBatchTest, training =False)
      diceEndoTest, diceEpiTest, jaccardEndoTest, jaccardEpiTest =  self.metrics(yBatchTest, yPredBatchTest)

      test_dices_endo.append(diceEndoTest)
      test_dices_epi.append(diceEpiTest)
      test_jaccards_endo.append(jaccardEndoTest)
      test_jaccards_epi.append(jaccardEpiTest)
    return np.mean(test_dices_endo), np.mean(test_dices_epi), np.mean(test_jaccards_endo), np.mean(test_jaccards_epi)
  def epoch_training(self,model,optimizer, trainDataset, testDataset, mb, stepTrain, alpha_loss, beta_loss):
    train_losses = []
    train_dices_endo =  []
    train_dices_epi = []
    train_jaccards_endo =  []
    train_jaccards_epi = []

    trainDataset = iter(trainDataset)  
    for _ in progress_bar(range(stepTrain),parent = mb):   
      with tf.GradientTape() as tape:
        image, y_true = next(trainDataset)
        y_pred = self.model(image, training = True)
        total_loss  =  self.loss(image, y_pred, y_true, alpha_loss, beta_loss)

      
      grad  = tape.gradient(total_loss, self.model.trainable_variables)
      optimizer.apply_gradients(zip(grad,self.model.trainable_variables))

      diceEndoTrain, diceEpiTrain, jaccardEndoTrain, jaccardEpiTrain =  self.metrics(y_true, y_pred)

      mb.child.comment = 'Train loss {:.4f}'.format(total_loss)

      train_losses.append(total_loss)
      train_dices_endo.append(diceEndoTrain)
      train_dices_epi.append(diceEpiTrain)
      train_jaccards_endo.append(jaccardEndoTrain)
      train_jaccards_epi.append(jaccardEpiTrain)

    trainLossMean = np.mean(train_losses)
    trainDiceEndoMean = np.mean(train_dices_endo)
    trainJaccardEndoMean = np.mean(train_jaccards_endo)
    trainDiceEpiMean = np.mean(train_dices_epi)
    trainJaccardEpiMean = np.mean(train_jaccards_epi)

    testDiceEndoMean, testDiceEpiMean, _, _ = self.evaluateTest(testDataset)

    return trainLossMean, trainDiceEndoMean, trainDiceEpiMean, testDiceEndoMean, testDiceEpiMean


  def train(self,num_epoch, reduceLrEpoch=15 , earlyStoping=31, minLr=1e-5, alpha_loss= 1e-6, beta_loss = 1,checkpoint_prefix = "./weightAlpha(1e-6)/ckpt_{score:.4f}.h5"):
    mb = master_bar(range(num_epoch))
    epochs_list = []
    history = dict()
    training_losses = []
    trainDiceEndo_list = []
    trainDiceEpi_list = []
    testDiceEndo_list = []
    testDiceEpi_list = []
    learningRate_list = []
    best_score  = 0
    count = 0
    for epoch in mb:
      count += 1
      epochs_list.append(epoch+1)

      trainLoss, trainDiceEndo, trainDiceEpi, testDiceEndo, testDiceEpi  \
      = self.epoch_training(self.model, self.optimizer, self.trainData, self.testData, mb, self.train_step, alpha_loss, beta_loss)

      mb.write('Finish train epoch {} with loss {:.4f} trainDiceEndo: {:.2f}, trainDiceEpi: {:.2f}, testDiceEndo: {:.2f},testDiceEpi: {:.2f}'.format(epoch+1, trainLoss, trainDiceEndo, trainDiceEpi, testDiceEndo, testDiceEpi ))

      training_losses.append(trainLoss)
      trainDiceEndo_list.append(trainDiceEndo)
      trainDiceEpi_list.append(trainDiceEpi)
      testDiceEndo_list.append(testDiceEndo)
      testDiceEpi_list.append(testDiceEpi)
      learningRate_list.append(self.learning_rate)

      if count % reduceLrEpoch ==0 :
        self.learning_rate = self.learning_rate * 0.5
        if self.learning_rate < minLr:
          self.learning_rate = minLr
        print('learning rate is set to : ',self.learning_rate)
        self.optimizer.learning_rate.assign(self.learning_rate )
    
      mb.update_graph([[epochs_list, training_losses]], [0,num_epoch], [0,0.1])
      if count == earlyStoping :
        break
      ### Check point here ###
      ### Check point follow testDiceEpi ###
      if best_score < testDiceEpi:
          count = 0
          mb.write(">>> Improved Dice-score EPI from {:.4f} to {:.4f}".format(best_score, testDiceEpi))
          best_score = testDiceEpi
          self.model.save_weights(checkpoint_prefix.format(score=best_score))
    history['epoch'] = epochs_list
    history['train_loss'] = training_losses
    history['train_dice_endo'] = trainDiceEndo_list
    history['train_dice_epi'] = trainDiceEpi_list
    history['test_dice_endo'] = testDiceEndo_list
    history['test_dice_epi'] = testDiceEpi_list
    # history['lr'] = learningRate_list
    return history

# %%
S = seg_net()
nhat = Mumford_Unet_vs2(S)
nhat.learning_rate = 0.001
nhat.trainData = train_dataset
nhat.testData = test_dataset
nhat.optimizer_fc(op_type = "nadam", op_param=nhat.learning_rate)

# %%
history = nhat.train(300,checkpoint_prefix="./weightAlpha(1e-6)/ckpt_{score:.4f}.h5")
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='141' class='' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       47.00% [141/300 58:16<1:05:42]
#     </div>
#
# Finish train epoch 1 with loss 0.2533 trainDiceEndo: 0.28, trainDiceEpi: 0.34, testDiceEndo: 0.08,testDiceEpi: 0.15<p>>>> Improved Dice-score EPI from 0.0000 to 0.1546<p>Finish train epoch 2 with loss 0.0883 trainDiceEndo: 0.54, trainDiceEpi: 0.59, testDiceEndo: 0.42,testDiceEpi: 0.53<p>>>> Improved Dice-score EPI from 0.1546 to 0.5271<p>Finish train epoch 3 with loss 0.0361 trainDiceEndo: 0.67, trainDiceEpi: 0.70, testDiceEndo: 0.41,testDiceEpi: 0.55<p>>>> Improved Dice-score EPI from 0.5271 to 0.5545<p>Finish train epoch 4 with loss 0.0237 trainDiceEndo: 0.76, trainDiceEpi: 0.79, testDiceEndo: 0.64,testDiceEpi: 0.69<p>>>> Improved Dice-score EPI from 0.5545 to 0.6915<p>Finish train epoch 5 with loss 0.0205 trainDiceEndo: 0.78, trainDiceEpi: 0.80, testDiceEndo: 0.69,testDiceEpi: 0.78<p>>>> Improved Dice-score EPI from 0.6915 to 0.7807<p>Finish train epoch 6 with loss 0.0167 trainDiceEndo: 0.80, trainDiceEpi: 0.82, testDiceEndo: 0.79,testDiceEpi: 0.83<p>>>> Improved Dice-score EPI from 0.7807 to 0.8327<p>Finish train epoch 7 with loss 0.0149 trainDiceEndo: 0.83, trainDiceEpi: 0.85, testDiceEndo: 0.79,testDiceEpi: 0.79<p>Finish train epoch 8 with loss 0.0136 trainDiceEndo: 0.84, trainDiceEpi: 0.86, testDiceEndo: 0.77,testDiceEpi: 0.81<p>Finish train epoch 9 with loss 0.0127 trainDiceEndo: 0.85, trainDiceEpi: 0.87, testDiceEndo: 0.84,testDiceEpi: 0.86<p>>>> Improved Dice-score EPI from 0.8327 to 0.8578<p>Finish train epoch 10 with loss 0.0122 trainDiceEndo: 0.85, trainDiceEpi: 0.87, testDiceEndo: 0.46,testDiceEpi: 0.52<p>Finish train epoch 11 with loss 0.0133 trainDiceEndo: 0.85, trainDiceEpi: 0.87, testDiceEndo: 0.85,testDiceEpi: 0.88<p>>>> Improved Dice-score EPI from 0.8578 to 0.8763<p>Finish train epoch 12 with loss 0.0112 trainDiceEndo: 0.86, trainDiceEpi: 0.88, testDiceEndo: 0.88,testDiceEpi: 0.88<p>>>> Improved Dice-score EPI from 0.8763 to 0.8772<p>Finish train epoch 13 with loss 0.0103 trainDiceEndo: 0.87, trainDiceEpi: 0.89, testDiceEndo: 0.86,testDiceEpi: 0.86<p>Finish train epoch 14 with loss 0.0100 trainDiceEndo: 0.88, trainDiceEpi: 0.90, testDiceEndo: 0.86,testDiceEpi: 0.88<p>>>> Improved Dice-score EPI from 0.8772 to 0.8799<p>Finish train epoch 15 with loss 0.0116 trainDiceEndo: 0.86, trainDiceEpi: 0.89, testDiceEndo: 0.80,testDiceEpi: 0.74<p>Finish train epoch 16 with loss 0.0099 trainDiceEndo: 0.88, trainDiceEpi: 0.91, testDiceEndo: 0.88,testDiceEpi: 0.87<p>Finish train epoch 17 with loss 0.0094 trainDiceEndo: 0.89, trainDiceEpi: 0.91, testDiceEndo: 0.89,testDiceEpi: 0.89<p>>>> Improved Dice-score EPI from 0.8799 to 0.8886<p>Finish train epoch 18 with loss 0.0090 trainDiceEndo: 0.89, trainDiceEpi: 0.91, testDiceEndo: 0.87,testDiceEpi: 0.89<p>Finish train epoch 19 with loss 0.0088 trainDiceEndo: 0.89, trainDiceEpi: 0.91, testDiceEndo: 0.89,testDiceEpi: 0.89<p>>>> Improved Dice-score EPI from 0.8886 to 0.8938<p>Finish train epoch 20 with loss 0.0086 trainDiceEndo: 0.89, trainDiceEpi: 0.92, testDiceEndo: 0.73,testDiceEpi: 0.74<p>Finish train epoch 21 with loss 0.0118 trainDiceEndo: 0.85, trainDiceEpi: 0.86, testDiceEndo: 0.81,testDiceEpi: 0.80<p>Finish train epoch 22 with loss 0.0098 trainDiceEndo: 0.87, trainDiceEpi: 0.90, testDiceEndo: 0.88,testDiceEpi: 0.89<p>Finish train epoch 23 with loss 0.0087 trainDiceEndo: 0.89, trainDiceEpi: 0.91, testDiceEndo: 0.87,testDiceEpi: 0.89<p>Finish train epoch 24 with loss 0.0083 trainDiceEndo: 0.90, trainDiceEpi: 0.92, testDiceEndo: 0.90,testDiceEpi: 0.90<p>>>> Improved Dice-score EPI from 0.8938 to 0.8991<p>Finish train epoch 25 with loss 0.0083 trainDiceEndo: 0.89, trainDiceEpi: 0.92, testDiceEndo: 0.84,testDiceEpi: 0.90<p>>>> Improved Dice-score EPI from 0.8991 to 0.9029<p>Finish train epoch 26 with loss 0.0093 trainDiceEndo: 0.88, trainDiceEpi: 0.91, testDiceEndo: 0.89,testDiceEpi: 0.90<p>Finish train epoch 27 with loss 0.0088 trainDiceEndo: 0.89, trainDiceEpi: 0.91, testDiceEndo: 0.87,testDiceEpi: 0.89<p>Finish train epoch 28 with loss 0.0083 trainDiceEndo: 0.89, trainDic ...
# learning rate is set to :  0.0005
# learning rate is set to :  0.00025
# learning rate is set to :  0.000125

# %%
# sio.savemat('./weightAlpha(1e-6)/history_LoriginAlpha(1e-6).mat',history)

# %%
nhat.model.load_weights('/content/drive/MyDrive/MS loss/weightAlpha(0)_uac/ckpt_0.9254.h5')

# %%
nhat.evaluateTest(test_dataset)
# Out:
# (0.92544603, 0.9281983, 0.885705, 0.8989112)

# %%
for i in range(x_test.shape[0]):
  y_pred = nhat.model(normalize(x_test[i:i+1],y_test[i:i+1]))
  y_predShow = np.argmax(y_pred,axis = -1)
  plt.figure(i+1)
  plt.subplot(131),plt.imshow(x_test[i,...,0],cmap='gray'),plt.title('image')
  plt.subplot(132),plt.imshow(y_predShow[0],cmap ='gray'),plt.title('predict')
  plt.subplot(133),plt.imshow(y_test[i,...,0],cmap='gray'),plt.title('groundtruth')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
hist = sio.loadmat('/content/drive/MyDrive/MS loss/weightAlpha(1e-6)_uac/history_LuacAlpha(1e-6).mat')

# %%
hist['train_loss'][0]
# Out:
# array([0.22333853, 0.07662826, 0.04083416, 0.02970164, 0.02350345,
#        0.02033389, 0.01591443, 0.01471676, 0.01408367, 0.0135718 ,
#        0.01199813, 0.01109523, 0.01264529, 0.01125071, 0.01002055,
#        0.00988795, 0.0097382 , 0.00924499, 0.00899095, 0.00936419,
#        0.00885799, 0.00869597, 0.01101004, 0.00889517, 0.00853252,
#        0.00914103, 0.00838611, 0.00840064, 0.00776776, 0.00777959,
#        0.00789468, 0.007944  , 0.00774474, 0.00805073, 0.00792514,
#        0.00770222, 0.00728081, 0.00743608, 0.00710296, 0.00836341,
#        0.0077332 , 0.00730935, 0.00774242, 0.0073465 , 0.0071768 ,
#        0.00850066, 0.00764257, 0.00725106, 0.00673049, 0.00662656,
#        0.00657555, 0.00658536, 0.0066442 , 0.00651941, 0.00684302,
#        0.00657597, 0.00648629, 0.00633075, 0.00689703, 0.00652409,
#        0.00622737, 0.00622713, 0.00620171, 0.00621367, 0.00610627,
#        0.00624056, 0.00617595, 0.0063142 , 0.00655824, 0.00614684,
#        0.00604089, 0.00596834, 0.00585742, 0.005848  , 0.00586757,
#        0.00593773, 0.0058805 , 0.00577774, 0.00574049, 0.00575009,
#        0.00575255, 0.00571189, 0.00577071, 0.00569901, 0.00566448,
#        0.00565152, 0.00572685, 0.0056397 , 0.00562609, 0.00567866,
#        0.00557096, 0.00558993, 0.00557768, 0.00556912, 0.0055487 ,
#        0.00555037, 0.00551907, 0.00563437, 0.00552647, 0.00553339,
#        0.00557734, 0.00553018, 0.00549951, 0.00551561, 0.00555601,
#        0.00551947, 0.00546823, 0.00546925, 0.00548376, 0.005493  ,
#        0.00547002, 0.00546742, 0.00548119, 0.00542884, 0.00540594,
#        0.0053979 , 0.00536292, 0.00535835, 0.00539155, 0.00535933,
#        0.00535925, 0.00537224, 0.00536333, 0.00534762, 0.00533688,
#        0.00533937, 0.00535466, 0.00532878, 0.00533583, 0.00533539,
#        0.00533265, 0.00534092, 0.0053144 , 0.00533692, 0.00532509,
#        0.00528721, 0.00531102, 0.00527479, 0.00525848, 0.00528827,
#        0.00527063, 0.00526206, 0.00528375, 0.00527305, 0.00526797,
#        0.0052631 , 0.00525055, 0.00524104, 0.00524336, 0.00526551,
#        0.00525142, 0.00522939, 0.00521683, 0.00521407, 0.00523516,
#        0.00525027, 0.00523118, 0.00523599, 0.00522644, 0.00521282,
#        0.00522792, 0.00521059, 0.00526132, 0.00522535, 0.00519802,
#        0.00523125, 0.00520682, 0.00520266, 0.00521887, 0.00520075,
#        0.00519883, 0.00522163, 0.00533838, 0.00531137, 0.00532481,
#        0.00534522, 0.00530228, 0.00529335, 0.00528784, 0.00534741,
#        0.00529668, 0.0052834 , 0.0052911 , 0.00525956, 0.00528814,
#        0.00527438, 0.00524979, 0.00521631, 0.00523184, 0.00519707,
#        0.00522271, 0.00518028, 0.00518416, 0.0051754 , 0.00518879,
#        0.00518337, 0.00515801, 0.00517883, 0.00517147, 0.00515116,
#        0.00514521, 0.0051494 , 0.00514554, 0.00513712, 0.00515151,
#        0.00513323, 0.00514103, 0.00513305], dtype=float32)

# %%
hist.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'epoch', 'train_loss', 'train_dice_endo', 'train_dice_epi', 'test_dice_endo', 'test_dice_epi'])

# %%
plt.plot(hist['train_loss'][0])
# plt.plot(hist['val_loss'])
# plt.plot(hist['train_dice_endo'][0])
# plt.plot(hist['train_dice_epi'][0])
plt.plot(hist['test_dice_endo'][0])
plt.plot(hist['test_dice_epi'][0])
plt.title('model loss/dice_coef')
plt.ylabel('loss/dice')
plt.xlabel('epoch')
plt.legend(['train_loss', 'test_dice_endo','test_dice_epi'])
plt.savefig('test.png')
plt.show()
